# %%
import os
from pathlib import Path
import requests
import tarfile
from tqdm import tqdm
import json
import numpy as np
import shutil

# %% [markdown]
# # Select which dataset you want to download, define seed and split ratio

# %%
dataset = "valid" # train, valid or test
np.random.seed(42)
split_ratio = 0.7

# %%
path = Path("dataset/nsynth-" + dataset)
if path.is_dir() and (path / "examples.json").is_file():
    print("Dataset already downloaded/extracted. Attempting to create train-test split.")
else:
    dlpath = Path(str(path.absolute()) + ".jsonwav.tar.gz")
    if not dlpath.is_file():
        print("Downloading dataset ({}).".format(dataset))
        url = "http://download.magenta.tensorflow.org/datasets/nsynth/nsynth-{}.jsonwav.tar.gz".format(dataset)
        print(url)
        r = requests.get(url, stream=True)
        total_size = int(r.headers.get('content-length', 0))
        block_size = 1024
        t = tqdm(total=total_size, unit='iB', unit_scale=True)
        with open(str(path.absolute()) + ".jsonwav.tar.gz", 'wb') as f:
            for data in r.iter_content(block_size):
                t.update(len(data))
                f.write(data)
        t.close()
        if total_size != 0 and t.n != total_size:
            print("Something went wrong with the download. If you download it manually into the dataset folder things will still work.")
    print("Extracting...")
    tar = tarfile.open(dlpath, 'r:gz')
    tar.extractall("dataset/")
    print("Creating train-test split. You may now delete the .tar.gz archives.")
    
with open(path / "examples.json") as f:
    jsondict = json.load(f)
    
keys = np.array(list(jsondict.keys()))
splits = [i.split('-') for i in keys]
instrument_str = [i[0] for i in splits]

# Get unique instruments in dataset
unique_inst = list(set(instrument_str))

# Make list of numpy arrays with all strings belonging to one instrument
instruments = []
for inst in unique_inst:
    instruments.append(keys[np.array(instrument_str) == inst])

# Create tr/te lists with random permutation (according to seed)
train = []
test = []
for inst in instruments:
    r = np.random.permutation(len(inst))
    i = int(len(inst) * split_ratio)
    train.extend(inst[r[:i]])
    test.extend(inst[r[i:]])

# Dict comprehension to get train-test split according to 
traind = {k:jsondict[k] for k in train}
testd = {k:jsondict[k] for k in test}

# Write new json files
with open(path / "train.json", "w") as f:
    json.dump(traind, f, indent=2)
with open(path / "test.json", "w") as f:
    json.dump(testd, f, indent=2)
    
# Create directories and copy .wav files
os.makedirs(path / "train", exist_ok=True)
os.makedirs(path / "test", exist_ok=True)
trainw = [x + ".wav" for x in train]
testw = [x + ".wav" for x in test]
for file in trainw:
    shutil.move(path / "audio" / file, path / "train" / file)
for file in testw:
    shutil.move(path / "audio" / file, path / "test" / file)
    
print("Successfully split the dataset. The folder 'audio' should now be empty. To reverse, just move all files from train/test folders back into audio and remove train/test(.json).")
# Out:
# Downloading dataset (valid).
# http://download.magenta.tensorflow.org/datasets/nsynth/nsynth-valid.jsonwav.tar.gz
# 100%|██████████| 1.07G/1.07G [04:21<00:00, 4.09MiB/s]
# Extracting...
# Creating train-test split. You may now delete the .tar.gz archives.
# Successfully split the dataset. The folder 'audio' should now be empty. To reverse, just move all files from train/test folders back into audio and remove train/test(.json).

# %%
dataset = "valid" # train, valid or test
np.random.seed(42)
split_ratio = 0.7
path = Path("dataset/nsynth-" + dataset)

# %%
with open(path / "examples.json") as f:
    jsondict = json.load(f)
    
keys = np.array(list(jsondict.keys()))
splits = [i.split('-') for i in keys]
instrument_str = [i[0] for i in splits]

# Get unique instruments in dataset
unique_inst = list(set(instrument_str))

# Make list of numpy arrays with all strings belonging to one instrument
instruments = []
for inst in unique_inst:
    instruments.append(keys[np.array(instrument_str) == inst])

# Create tr/te lists with random permutation (according to seed)
train = []
test = []
for inst in instruments:
    r = np.random.permutation(len(inst))
    i = int(len(inst) * split_ratio)
    train.extend(inst[r[:i]])
    test.extend(inst[r[i:]])

# Dict comprehension to get train-test split according to 
traind = {k:jsondict[k] for k in train}
testd = {k:jsondict[k] for k in test}

# %%
list(traind.keys())
# Out:
# ['guitar_acoustic_030-039-075',
#  'guitar_acoustic_030-026-127',
#  'guitar_acoustic_030-023-050',
#  'guitar_acoustic_030-028-050',
#  'guitar_acoustic_030-094-100',
#  'guitar_acoustic_030-072-025',
#  'guitar_acoustic_030-086-127',
#  'guitar_acoustic_030-050-025',
#  'guitar_acoustic_030-043-050',
#  'guitar_acoustic_030-097-025',
#  'guitar_acoustic_030-041-075',
#  'guitar_acoustic_030-075-127',
#  'guitar_acoustic_030-045-127',
#  'guitar_acoustic_030-050-127',
#  'guitar_acoustic_030-064-127',
#  'guitar_acoustic_030-107-025',
#  'guitar_acoustic_030-075-025',
#  'guitar_acoustic_030-034-100',
#  'guitar_acoustic_030-103-025',
#  'guitar_acoustic_030-069-127',
#  'guitar_acoustic_030-102-075',
#  'guitar_acoustic_030-043-025',
#  'guitar_acoustic_030-057-075',
#  'guitar_acoustic_030-055-050',
#  'guitar_acoustic_030-091-025',
#  'guitar_acoustic_030-080-100',
#  'guitar_acoustic_030-093-050',
#  'guitar_acoustic_030-058-075',
#  'guitar_acoustic_030-094-050',
#  'guitar_acoustic_030-038-025',
#  'guitar_acoustic_030-083-025',
#  'guitar_acoustic_030-057-127',
#  'guitar_acoustic_030-038-075',
#  'guitar_acoustic_030-067-075',
#  'guitar_acoustic_030-098-050',
#  'guitar_acoustic_030-022-100',
#  'guitar_acoustic_030-089-050',
#  'guitar_acoustic_030-042-127',
#  'guitar_acoustic_030-030-050',
#  'guitar_acoustic_030-032-025',
#  'guitar_acoustic_030-105-075',
#  'guitar_acoustic_030-080-075',
#  'guitar_acoustic_030-069-050',
#  'guitar_acoustic_030-089-075',
#  'guitar_acoustic_030-032-100',
#  'guitar_acoustic_030-089-100',
#  'guitar_acoustic_030-091-100',
#  'guitar_acoustic_030-074-100',
#  'guitar_acoustic_030-060-025',
#  'guitar_acoustic_030-041-025',
#  'guitar_acoustic_030-100-050',
#  'guitar_acoustic_030-041-127',
#  'guitar_acoustic_030-100-100',
#  'guitar_acoustic_030-082-127',
#  'guitar_acoustic_030-086-075',
#  'guitar_acoustic_030-024-100',
#  'guitar_acoustic_030-041-050',
#  'guitar_acoustic_030-092-100',
#  'guitar_acoustic_030-088-100',
#  'guitar_acoustic_030-035-100',
#  'guitar_acoustic_030-058-100',
#  'guitar_acoustic_030-060-127',
#  'guitar_acoustic_030-076-075',
#  'guitar_acoustic_030-076-127',
#  'guitar_acoustic_030-072-075',
#  'guitar_acoustic_030-097-127',
#  'guitar_acoustic_030-070-075',
#  'guitar_acoustic_030-093-075',
#  'guitar_acoustic_030-040-100',
#  'guitar_acoustic_030-062-075',
#  'guitar_acoustic_030-030-025',
#  'guitar_acoustic_030-045-025',
#  'guitar_acoustic_030-045-075',
#  'guitar_acoustic_030-056-075',
#  'guitar_acoustic_030-094-025',
#  'guitar_acoustic_030-021-025',
#  'guitar_acoustic_030-046-025',
#  'guitar_acoustic_030-070-127',
#  'guitar_acoustic_030-106-075',
#  'guitar_acoustic_030-103-050',
#  'guitar_acoustic_030-068-050',
#  'guitar_acoustic_030-056-127',
#  'guitar_acoustic_030-051-100',
#  'guitar_acoustic_030-053-025',
#  'guitar_acoustic_030-059-127',
#  'guitar_acoustic_030-105-127',
#  'guitar_acoustic_030-035-050',
#  'guitar_acoustic_030-090-050',
#  'guitar_acoustic_030-106-025',
#  'guitar_acoustic_030-050-100',
#  'guitar_acoustic_030-078-100',
#  'guitar_acoustic_030-023-025',
#  'guitar_acoustic_030-047-025',
#  'guitar_acoustic_030-101-127',
#  'guitar_acoustic_030-022-127',
#  'guitar_acoustic_030-045-050',
#  'guitar_acoustic_030-068-025',
#  'guitar_acoustic_030-058-025',
#  'guitar_acoustic_030-040-025',
#  'guitar_acoustic_030-039-025',
#  'guitar_acoustic_030-063-100',
#  'guitar_acoustic_030-101-100',
#  'guitar_acoustic_030-104-127',
#  'guitar_acoustic_030-083-100',
#  'guitar_acoustic_030-047-050',
#  'guitar_acoustic_030-082-025',
#  'guitar_acoustic_030-021-100',
#  'guitar_acoustic_030-062-100',
#  'guitar_acoustic_030-098-025',
#  'guitar_acoustic_030-033-025',
#  'guitar_acoustic_030-107-127',
#  'guitar_acoustic_030-048-127',
#  'guitar_acoustic_030-034-075',
#  'reed_acoustic_037-076-075',
#  'reed_acoustic_037-046-025',
#  'reed_acoustic_037-055-127',
#  'reed_acoustic_037-064-050',
#  'reed_acoustic_037-072-127',
#  'reed_acoustic_037-058-127',
#  'reed_acoustic_037-055-075',
#  'reed_acoustic_037-034-075',
#  'reed_acoustic_037-074-127',
#  'reed_acoustic_037-046-100',
#  'reed_acoustic_037-062-050',
#  'reed_acoustic_037-034-025',
#  'reed_acoustic_037-037-025',
#  'reed_acoustic_037-043-075',
#  'reed_acoustic_037-057-025',
#  'reed_acoustic_037-051-025',
#  'reed_acoustic_037-076-100',
#  'reed_acoustic_037-056-050',
#  'reed_acoustic_037-049-075',
#  'reed_acoustic_037-055-025',
#  'reed_acoustic_037-040-025',
#  'reed_acoustic_037-053-127',
#  'reed_acoustic_037-039-025',
#  'reed_acoustic_037-056-075',
#  'reed_acoustic_037-061-025',
#  'reed_acoustic_037-052-100',
#  'reed_acoustic_037-048-100',
#  'reed_acoustic_037-076-025',
#  'reed_acoustic_037-054-050',
#  'reed_acoustic_037-072-025',
#  'reed_acoustic_037-041-075',
#  'reed_acoustic_037-062-100',
#  'reed_acoustic_037-059-025',
#  'reed_acoustic_037-036-025',
#  'reed_acoustic_037-048-025',
#  'reed_acoustic_037-064-100',
#  'reed_acoustic_037-042-127',
#  'reed_acoustic_037-053-050',
#  'reed_acoustic_037-051-127',
#  'reed_acoustic_037-042-100',
#  'reed_acoustic_037-039-127',
#  'reed_acoustic_037-061-100',
#  'reed_acoustic_037-069-025',
#  'reed_acoustic_037-034-100',
#  'reed_acoustic_037-046-127',
#  'reed_acoustic_037-062-075',
#  'reed_acoustic_037-034-050',
#  'reed_acoustic_037-032-050',
#  'reed_acoustic_037-060-050',
#  'reed_acoustic_037-059-075',
#  'reed_acoustic_037-060-075',
#  'reed_acoustic_037-065-127',
#  'reed_acoustic_037-071-050',
#  'reed_acoustic_037-063-050',
#  'reed_acoustic_037-058-025',
#  'reed_acoustic_037-036-050',
#  'reed_acoustic_037-043-025',
#  'reed_acoustic_037-036-127',
#  'reed_acoustic_037-049-100',
#  'reed_acoustic_037-064-025',
#  'reed_acoustic_037-063-075',
#  'reed_acoustic_037-059-100',
#  'reed_acoustic_037-053-100',
#  'reed_acoustic_037-043-127',
#  'reed_acoustic_037-066-127',
#  'reed_acoustic_037-041-100',
#  'reed_acoustic_037-061-050',
#  'reed_acoustic_037-076-127',
#  'reed_acoustic_037-075-100',
#  'reed_acoustic_037-067-025',
#  'reed_acoustic_037-070-100',
#  'reed_acoustic_037-045-050',
#  'reed_acoustic_037-072-075',
#  'reed_acoustic_037-063-127',
#  'reed_acoustic_037-045-025',
#  'reed_acoustic_037-070-025',
#  'reed_acoustic_037-073-127',
#  'reed_acoustic_037-059-050',
#  'reed_acoustic_037-041-025',
#  'reed_acoustic_037-075-075',
#  'reed_acoustic_037-058-050',
#  'reed_acoustic_037-053-025',
#  'reed_acoustic_037-067-075',
#  'reed_acoustic_037-064-075',
#  'reed_acoustic_037-068-025',
#  'reed_acoustic_037-043-050',
#  'reed_acoustic_037-071-025',
#  'reed_acoustic_037-039-100',
#  'reed_acoustic_037-058-100',
#  'reed_acoustic_037-056-127',
#  'reed_acoustic_037-044-025',
#  'reed_acoustic_037-065-025',
#  'reed_acoustic_037-044-050',
#  'reed_acoustic_037-059-127',
#  'reed_acoustic_037-042-025',
#  'reed_acoustic_037-036-100',
#  'reed_acoustic_037-032-100',
#  'reed_acoustic_037-073-100',
#  'reed_acoustic_037-063-025',
#  'reed_acoustic_037-052-050',
#  'reed_acoustic_037-040-050',
#  'reed_acoustic_037-041-127',
#  'reed_acoustic_037-069-050',
#  'reed_acoustic_037-031-025',
#  'reed_acoustic_037-071-100',
#  'reed_acoustic_037-038-127',
#  'reed_acoustic_037-031-100',
#  'reed_acoustic_037-039-050',
#  'reed_acoustic_037-061-075',
#  'reed_acoustic_037-047-100',
#  'reed_acoustic_037-053-075',
#  'reed_acoustic_037-046-050',
#  'reed_acoustic_037-038-075',
#  'reed_acoustic_037-049-050',
#  'reed_acoustic_037-048-075',
#  'reed_acoustic_037-057-100',
#  'reed_acoustic_037-071-075',
#  'reed_acoustic_037-070-127',
#  'reed_acoustic_037-040-100',
#  'reed_acoustic_037-072-100',
#  'vocal_acoustic_000-051-050',
#  'vocal_acoustic_000-055-100',
#  'vocal_acoustic_000-065-025',
#  'vocal_acoustic_000-057-100',
#  'vocal_acoustic_000-050-075',
#  'vocal_acoustic_000-056-050',
#  'vocal_acoustic_000-053-075',
#  'vocal_acoustic_000-066-075',
#  'vocal_acoustic_000-052-100',
#  'vocal_acoustic_000-062-100',
#  'vocal_acoustic_000-070-025',
#  'vocal_acoustic_000-056-100',
#  'vocal_acoustic_000-063-127',
#  'vocal_acoustic_000-065-050',
#  'vocal_acoustic_000-058-075',
#  'vocal_acoustic_000-060-025',
#  'vocal_acoustic_000-068-100',
#  'vocal_acoustic_000-058-025',
#  'vocal_acoustic_000-070-050',
#  'vocal_acoustic_000-061-025',
#  'vocal_acoustic_000-059-050',
#  'vocal_acoustic_000-069-127',
#  'vocal_acoustic_000-055-075',
#  'vocal_acoustic_000-066-100',
#  'vocal_acoustic_000-059-025',
#  'vocal_acoustic_000-053-025',
#  'vocal_acoustic_000-062-075',
#  'vocal_acoustic_000-050-127',
#  'vocal_acoustic_000-061-050',
#  'vocal_acoustic_000-053-127',
#  'vocal_acoustic_000-070-100',
#  'vocal_acoustic_000-054-025',
#  'vocal_acoustic_000-058-100',
#  'vocal_acoustic_000-069-075',
#  'vocal_acoustic_000-063-075',
#  'vocal_acoustic_000-065-127',
#  'vocal_acoustic_000-063-050',
#  'vocal_acoustic_000-060-127',
#  'vocal_acoustic_000-057-075',
#  'vocal_acoustic_000-052-050',
#  'vocal_acoustic_000-052-075',
#  'vocal_acoustic_000-053-050',
#  'vocal_acoustic_000-059-075',
#  'vocal_acoustic_000-063-100',
#  'vocal_acoustic_000-051-075',
#  'vocal_acoustic_000-055-127',
#  'vocal_acoustic_000-069-100',
#  'vocal_acoustic_000-058-050',
#  'vocal_acoustic_000-065-075',
#  'vocal_acoustic_000-050-100',
#  'vocal_acoustic_000-051-025',
#  'vocal_acoustic_000-064-025',
#  'vocal_acoustic_000-068-050',
#  'vocal_acoustic_000-051-100',
#  'vocal_acoustic_000-066-050',
#  'vocal_acoustic_000-057-050',
#  'vocal_acoustic_000-067-127',
#  'vocal_acoustic_000-061-100',
#  'keyboard_electronic_001-028-025',
#  'keyboard_electronic_001-021-075',
#  'keyboard_electronic_001-037-025',
#  'keyboard_electronic_001-055-127',
#  'keyboard_electronic_001-031-050',
#  'keyboard_electronic_001-096-075',
#  'keyboard_electronic_001-069-025',
#  'keyboard_electronic_001-057-025',
#  'keyboard_electronic_001-067-075',
#  'keyboard_electronic_001-083-075',
#  'keyboard_electronic_001-040-050',
#  'keyboard_electronic_001-070-127',
#  'keyboard_electronic_001-024-100',
#  'keyboard_electronic_001-103-050',
#  'keyboard_electronic_001-103-127',
#  'keyboard_electronic_001-094-100',
#  'keyboard_electronic_001-060-075',
#  'keyboard_electronic_001-094-025',
#  'keyboard_electronic_001-022-050',
#  'keyboard_electronic_001-034-025',
#  'keyboard_electronic_001-045-025',
#  'keyboard_electronic_001-034-075',
#  'keyboard_electronic_001-063-025',
#  'keyboard_electronic_001-027-025',
#  'keyboard_electronic_001-056-075',
#  'keyboard_electronic_001-071-127',
#  'keyboard_electronic_001-091-075',
#  'keyboard_electronic_001-031-127',
#  'keyboard_electronic_001-027-127',
#  'keyboard_electronic_001-090-050',
#  'keyboard_electronic_001-097-127',
#  'keyboard_electronic_001-102-025',
#  'keyboard_electronic_001-089-025',
#  'keyboard_electronic_001-034-050',
#  'keyboard_electronic_001-069-075',
#  'keyboard_electronic_001-076-100',
#  'keyboard_electronic_001-074-075',
#  'keyboard_electronic_001-067-100',
#  'keyboard_electronic_001-105-127',
#  'keyboard_electronic_001-060-025',
#  'keyboard_electronic_001-067-050',
#  'keyboard_electronic_001-021-050',
#  'keyboard_electronic_001-095-127',
#  'keyboard_electronic_001-043-127',
#  'keyboard_electronic_001-058-127',
#  'keyboard_electronic_001-088-050',
#  'keyboard_electronic_001-028-127',
#  'keyboard_electronic_001-053-075',
#  'keyboard_electronic_001-098-127',
#  'keyboard_electronic_001-022-100',
#  'keyboard_electronic_001-075-075',
#  'keyboard_electronic_001-081-025',
#  'keyboard_electronic_001-066-100',
#  'keyboard_electronic_001-086-127',
#  'keyboard_electronic_001-044-127',
#  'keyboard_electronic_001-078-025',
#  'keyboard_electronic_001-092-100',
#  'keyboard_electronic_001-063-050',
#  'keyboard_electronic_001-081-100',
#  'keyboard_electronic_001-083-127',
#  'keyboard_electronic_001-066-050',
#  'keyboard_electronic_001-106-025',
#  'keyboard_electronic_001-032-050',
#  'keyboard_electronic_001-107-127',
#  'keyboard_electronic_001-025-127',
#  'keyboard_electronic_001-040-100',
#  'keyboard_electronic_001-049-025',
#  'keyboard_electronic_001-050-100',
#  'keyboard_electronic_001-029-050',
#  'keyboard_electronic_001-058-050',
#  'keyboard_electronic_001-045-100',
#  'keyboard_electronic_001-084-075',
#  'keyboard_electronic_001-075-100',
#  'keyboard_electronic_001-068-100',
#  'keyboard_electronic_001-039-075',
#  'keyboard_electronic_001-064-100',
#  'keyboard_electronic_001-073-100',
#  'keyboard_electronic_001-038-075',
#  'keyboard_electronic_001-098-075',
#  'keyboard_electronic_001-055-075',
#  'keyboard_electronic_001-054-100',
#  'keyboard_electronic_001-057-127',
#  'keyboard_electronic_001-057-050',
#  'keyboard_electronic_001-088-100',
#  'keyboard_electronic_001-032-100',
#  'keyboard_electronic_001-081-127',
#  'keyboard_electronic_001-092-050',
#  'keyboard_electronic_001-088-025',
#  'keyboard_electronic_001-054-127',
#  'keyboard_electronic_001-106-075',
#  'keyboard_electronic_001-070-050',
#  'keyboard_electronic_001-041-100',
#  'keyboard_electronic_001-055-100',
#  'keyboard_electronic_001-105-100',
#  'keyboard_electronic_001-078-050',
#  'keyboard_electronic_001-079-127',
#  'keyboard_electronic_001-066-127',
#  'keyboard_electronic_001-028-075',
#  'keyboard_electronic_001-036-127',
#  'keyboard_electronic_001-021-100',
#  'keyboard_electronic_001-090-127',
#  'keyboard_electronic_001-061-025',
#  'keyboard_electronic_001-083-100',
#  'keyboard_electronic_001-068-025',
#  'keyboard_electronic_001-090-100',
#  'keyboard_electronic_001-060-050',
#  'keyboard_electronic_001-049-100',
#  'keyboard_electronic_001-036-025',
#  'keyboard_electronic_001-046-075',
#  'keyboard_electronic_001-021-025',
#  'keyboard_electronic_001-037-050',
#  'keyboard_electronic_001-106-050',
#  'keyboard_electronic_001-097-050',
#  'keyboard_electronic_001-085-025',
#  'keyboard_electronic_001-050-050',
#  'keyboard_electronic_001-059-075',
#  'keyboard_electronic_001-089-075',
#  'keyboard_electronic_001-090-075',
#  'keyboard_electronic_001-038-025',
#  'keyboard_electronic_001-034-127',
#  'keyboard_electronic_001-108-025',
#  'keyboard_electronic_001-094-075',
#  'keyboard_electronic_001-023-100',
#  'keyboard_electronic_001-035-100',
#  'keyboard_electronic_001-054-025',
#  'keyboard_electronic_001-104-075',
#  'keyboard_electronic_001-028-100',
#  'keyboard_electronic_001-043-050',
#  'keyboard_electronic_001-088-127',
#  'keyboard_electronic_001-087-025',
#  'keyboard_electronic_001-036-050',
#  'keyboard_electronic_001-055-050',
#  'keyboard_electronic_001-100-127',
#  'keyboard_electronic_001-093-100',
#  'keyboard_electronic_001-081-075',
#  'keyboard_electronic_001-065-075',
#  'keyboard_electronic_001-048-025',
#  'keyboard_electronic_001-063-100',
#  'keyboard_electronic_001-093-025',
#  'keyboard_electronic_001-047-100',
#  'keyboard_electronic_001-102-100',
#  'keyboard_electronic_001-076-075',
#  'keyboard_electronic_001-082-075',
#  'keyboard_electronic_001-064-025',
#  'keyboard_electronic_001-105-025',
#  'keyboard_electronic_001-033-075',
#  'keyboard_electronic_001-080-075',
#  'keyboard_electronic_001-089-100',
#  'keyboard_electronic_001-079-050',
#  'keyboard_electronic_001-050-127',
#  'keyboard_electronic_001-036-075',
#  'keyboard_electronic_001-033-127',
#  'keyboard_electronic_001-061-100',
#  'keyboard_electronic_001-088-075',
#  'keyboard_electronic_001-075-127',
#  'keyboard_electronic_001-099-025',
#  'keyboard_electronic_001-073-127',
#  'keyboard_electronic_001-081-050',
#  'keyboard_electronic_001-069-050',
#  'keyboard_electronic_001-022-127',
#  'keyboard_electronic_001-043-025',
#  'keyboard_electronic_001-087-075',
#  'keyboard_electronic_001-045-127',
#  'keyboard_electronic_001-069-100',
#  'keyboard_electronic_001-051-075',
#  'keyboard_electronic_001-070-075',
#  'keyboard_electronic_001-036-100',
#  'keyboard_electronic_001-080-025',
#  'keyboard_electronic_001-064-127',
#  'keyboard_electronic_001-074-050',
#  'keyboard_electronic_001-077-075',
#  'keyboard_electronic_001-096-025',
#  'keyboard_electronic_001-079-100',
#  'keyboard_electronic_001-032-025',
#  'keyboard_electronic_001-082-050',
#  'keyboard_electronic_001-063-127',
#  'keyboard_electronic_001-035-025',
#  'keyboard_electronic_001-060-127',
#  'keyboard_electronic_001-086-100',
#  'keyboard_electronic_001-039-100',
#  'keyboard_electronic_001-044-100',
#  'keyboard_electronic_001-082-127',
#  'keyboard_electronic_001-058-075',
#  'keyboard_electronic_001-091-050',
#  'keyboard_electronic_001-091-025',
#  'keyboard_electronic_001-097-075',
#  'keyboard_electronic_001-072-075',
#  'keyboard_electronic_001-094-050',
#  'keyboard_electronic_001-104-100',
#  'keyboard_electronic_001-056-050',
#  'keyboard_electronic_001-085-100',
#  'keyboard_electronic_001-083-025',
#  'keyboard_electronic_001-099-050',
#  'keyboard_electronic_001-049-075',
#  'keyboard_electronic_001-098-100',
#  'keyboard_electronic_001-065-025',
#  'keyboard_electronic_001-073-050',
#  'keyboard_electronic_001-033-100',
#  'keyboard_electronic_001-030-127',
#  'keyboard_electronic_001-077-025',
#  'keyboard_electronic_001-077-127',
#  'keyboard_electronic_001-026-050',
#  'keyboard_electronic_001-046-025',
#  'keyboard_electronic_001-056-127',
#  'keyboard_electronic_001-041-050',
#  'keyboard_electronic_001-085-127',
#  'keyboard_electronic_001-047-025',
#  'keyboard_electronic_001-050-075',
#  'keyboard_electronic_001-065-127',
#  'keyboard_electronic_001-072-025',
#  'keyboard_electronic_001-042-100',
#  'keyboard_electronic_001-090-025',
#  'keyboard_electronic_001-055-025',
#  'keyboard_electronic_001-070-025',
#  'keyboard_electronic_001-052-127',
#  'keyboard_electronic_001-076-127',
#  'keyboard_electronic_001-106-100',
#  'keyboard_electronic_001-107-025',
#  'keyboard_electronic_001-077-100',
#  'keyboard_electronic_001-034-100',
#  'keyboard_electronic_001-078-100',
#  'keyboard_electronic_001-037-100',
#  'keyboard_electronic_001-033-050',
#  'keyboard_electronic_001-091-127',
#  'keyboard_electronic_001-023-127',
#  'keyboard_electronic_001-077-050',
#  'keyboard_electronic_001-073-075',
#  'keyboard_electronic_001-087-127',
#  'keyboard_electronic_001-022-025',
#  'keyboard_electronic_001-105-050',
#  'keyboard_electronic_001-078-075',
#  'keyboard_electronic_001-029-025',
#  'keyboard_electronic_001-035-075',
#  'keyboard_electronic_001-027-100',
#  'keyboard_electronic_001-047-050',
#  'keyboard_electronic_001-067-127',
#  'keyboard_electronic_001-085-050',
#  'keyboard_electronic_001-079-025',
#  'keyboard_electronic_001-048-100',
#  'keyboard_electronic_001-084-025',
#  'bass_synthetic_135-058-100',
#  'bass_synthetic_135-042-050',
#  'bass_synthetic_135-100-075',
#  'bass_synthetic_135-080-127',
#  'bass_synthetic_135-069-050',
#  'bass_synthetic_135-107-100',
#  'bass_synthetic_135-046-127',
#  'bass_synthetic_135-058-025',
#  'bass_synthetic_135-050-127',
#  'bass_synthetic_135-045-127',
#  'bass_synthetic_135-088-075',
#  'bass_synthetic_135-108-100',
#  'bass_synthetic_135-057-100',
#  'bass_synthetic_135-057-025',
#  'bass_synthetic_135-095-025',
#  'bass_synthetic_135-062-127',
#  'bass_synthetic_135-044-127',
#  'bass_synthetic_135-098-050',
#  'bass_synthetic_135-071-025',
#  'bass_synthetic_135-044-075',
#  'bass_synthetic_135-026-075',
#  'bass_synthetic_135-051-075',
#  'bass_synthetic_135-070-075',
#  'bass_synthetic_135-094-025',
#  'bass_synthetic_135-049-050',
#  'bass_synthetic_135-105-050',
#  'bass_synthetic_135-100-050',
#  'bass_synthetic_135-048-127',
#  'bass_synthetic_135-032-100',
#  'bass_synthetic_135-082-075',
#  'bass_synthetic_135-099-127',
#  'bass_synthetic_135-032-127',
#  'bass_synthetic_135-081-050',
#  'bass_synthetic_135-040-127',
#  'bass_synthetic_135-106-050',
#  'bass_synthetic_135-091-127',
#  'bass_synthetic_135-082-127',
#  'bass_synthetic_135-104-050',
#  'bass_synthetic_135-103-075',
#  'bass_synthetic_135-081-075',
#  'bass_synthetic_135-021-050',
#  'bass_synthetic_135-023-127',
#  'bass_synthetic_135-043-050',
#  'bass_synthetic_135-042-100',
#  'bass_synthetic_135-023-075',
#  'bass_synthetic_135-068-050',
#  'bass_synthetic_135-033-050',
#  'bass_synthetic_135-027-100',
#  'bass_synthetic_135-025-025',
#  'bass_synthetic_135-094-050',
#  'bass_synthetic_135-053-075',
#  'bass_synthetic_135-088-100',
#  'bass_synthetic_135-094-127',
#  'bass_synthetic_135-058-050',
#  'bass_synthetic_135-080-075',
#  'bass_synthetic_135-093-127',
#  'bass_synthetic_135-041-075',
#  'bass_synthetic_135-098-025',
#  'bass_synthetic_135-055-127',
#  'bass_synthetic_135-106-127',
#  'bass_synthetic_135-062-025',
#  'bass_synthetic_135-107-025',
#  'bass_synthetic_135-027-050',
#  'bass_synthetic_135-101-050',
#  'bass_synthetic_135-028-050',
#  'bass_synthetic_135-088-127',
#  'bass_synthetic_135-032-075',
#  'bass_synthetic_135-071-075',
#  'bass_synthetic_135-079-050',
#  'bass_synthetic_135-035-100',
#  'bass_synthetic_135-060-025',
#  'bass_synthetic_135-068-025',
#  'bass_synthetic_135-104-025',
#  'bass_synthetic_135-080-025',
#  'bass_synthetic_135-039-025',
#  'bass_synthetic_135-090-025',
#  'bass_synthetic_135-029-100',
#  'bass_synthetic_135-038-100',
#  'bass_synthetic_135-086-025',
#  'bass_synthetic_135-097-075',
#  'bass_synthetic_135-096-075',
#  'bass_synthetic_135-051-100',
#  'bass_synthetic_135-066-025',
#  'bass_synthetic_135-082-050',
#  'bass_synthetic_135-048-100',
#  'bass_synthetic_135-107-127',
#  'bass_synthetic_135-030-050',
#  'bass_synthetic_135-107-075',
#  'bass_synthetic_135-048-025',
#  'bass_synthetic_135-072-050',
#  'bass_synthetic_135-025-075',
#  'bass_synthetic_135-064-075',
#  'bass_synthetic_135-029-075',
#  'bass_synthetic_135-092-127',
#  'bass_synthetic_135-034-127',
#  'bass_synthetic_135-047-127',
#  'bass_synthetic_135-108-050',
#  'bass_synthetic_135-047-075',
#  'bass_synthetic_135-059-100',
#  'bass_synthetic_135-078-127',
#  'bass_synthetic_135-089-127',
#  'bass_synthetic_135-104-100',
#  'bass_synthetic_135-099-075',
#  'bass_synthetic_135-095-050',
#  'bass_synthetic_135-048-050',
#  'bass_synthetic_135-073-100',
#  'bass_synthetic_135-060-100',
#  'bass_synthetic_135-103-127',
#  'bass_synthetic_135-078-025',
#  'bass_synthetic_135-045-100',
#  'bass_synthetic_135-059-075',
#  'bass_synthetic_135-050-050',
#  'bass_synthetic_135-074-025',
#  'bass_synthetic_135-104-127',
#  'bass_synthetic_135-092-025',
#  'bass_synthetic_135-079-025',
#  'bass_synthetic_135-043-075',
#  'bass_synthetic_135-053-025',
#  'bass_synthetic_135-085-075',
#  'bass_synthetic_135-030-100',
#  'bass_synthetic_135-079-075',
#  'bass_synthetic_135-041-100',
#  'bass_synthetic_135-037-075',
#  'bass_synthetic_135-100-100',
#  'bass_synthetic_135-026-100',
#  'bass_synthetic_135-089-050',
#  'bass_synthetic_135-024-100',
#  'bass_synthetic_135-031-100',
#  'bass_synthetic_135-093-025',
#  'bass_synthetic_135-058-075',
#  'bass_synthetic_135-046-100',
#  'bass_synthetic_135-103-025',
#  'bass_synthetic_135-052-025',
#  'bass_synthetic_135-070-025',
#  'bass_synthetic_135-036-050',
#  'bass_synthetic_135-059-127',
#  'bass_synthetic_135-061-127',
#  'bass_synthetic_135-089-100',
#  'bass_synthetic_135-073-127',
#  'bass_synthetic_135-032-050',
#  'bass_synthetic_135-051-025',
#  'bass_synthetic_135-108-025',
#  'bass_synthetic_135-093-075',
#  'bass_synthetic_135-101-025',
#  'bass_synthetic_135-037-025',
#  'bass_synthetic_135-102-127',
#  'bass_synthetic_135-056-075',
#  'bass_synthetic_135-090-050',
#  'bass_synthetic_135-038-050',
#  'bass_synthetic_135-046-025',
#  'bass_synthetic_135-092-100',
#  'bass_synthetic_135-034-075',
#  'bass_synthetic_135-049-075',
#  'bass_synthetic_135-035-127',
#  'bass_synthetic_135-030-075',
#  'bass_synthetic_135-034-025',
#  'bass_synthetic_135-090-127',
#  'bass_synthetic_135-031-050',
#  'bass_synthetic_135-081-127',
#  'bass_synthetic_135-083-050',
#  'bass_synthetic_135-058-127',
#  'bass_synthetic_135-050-100',
#  'bass_synthetic_135-105-075',
#  'bass_synthetic_135-033-127',
#  'bass_synthetic_135-047-100',
#  'bass_synthetic_135-078-050',
#  'bass_synthetic_135-091-075',
#  'bass_synthetic_135-072-127',
#  'bass_synthetic_135-065-127',
#  'bass_synthetic_135-028-025',
#  'bass_synthetic_135-024-075',
#  'bass_synthetic_135-103-100',
#  'bass_synthetic_135-045-025',
#  'bass_synthetic_135-039-100',
#  'bass_synthetic_135-082-100',
#  'bass_synthetic_135-024-050',
#  'bass_synthetic_135-028-100',
#  'bass_synthetic_135-077-075',
#  'bass_synthetic_135-075-127',
#  'bass_synthetic_135-088-050',
#  'bass_synthetic_135-043-025',
#  'bass_synthetic_135-068-127',
#  'bass_synthetic_135-056-050',
#  'bass_synthetic_135-086-075',
#  'bass_synthetic_135-091-050',
#  'bass_synthetic_135-040-050',
#  'bass_synthetic_135-046-050',
#  'bass_synthetic_135-090-075',
#  'bass_synthetic_135-063-127',
#  'bass_synthetic_135-033-075',
#  'bass_synthetic_135-085-025',
#  'bass_synthetic_135-072-075',
#  'bass_synthetic_135-064-025',
#  'bass_synthetic_135-074-050',
#  'bass_synthetic_135-034-050',
#  'bass_synthetic_135-064-127',
#  'bass_synthetic_135-075-100',
#  'bass_synthetic_135-025-050',
#  'bass_synthetic_135-105-127',
#  'bass_synthetic_135-021-025',
#  'bass_synthetic_135-086-100',
#  'bass_synthetic_135-056-127',
#  'bass_synthetic_135-057-050',
#  'bass_synthetic_135-057-075',
#  'bass_synthetic_135-026-050',
#  'bass_synthetic_135-077-100',
#  'bass_synthetic_135-052-050',
#  'bass_synthetic_135-085-100',
#  'bass_synthetic_135-039-127',
#  'bass_synthetic_135-024-025',
#  'bass_synthetic_135-074-127',
#  'bass_synthetic_135-108-127',
#  'bass_synthetic_135-084-025',
#  'bass_synthetic_135-033-100',
#  'bass_synthetic_135-056-025',
#  'bass_synthetic_135-063-100',
#  'bass_synthetic_135-069-127',
#  'bass_synthetic_135-031-025',
#  'bass_synthetic_135-067-127',
#  'bass_synthetic_135-061-050',
#  'bass_synthetic_135-028-075',
#  'bass_synthetic_135-054-075',
#  'bass_synthetic_135-060-050',
#  'bass_synthetic_135-081-100',
#  'bass_synthetic_135-083-025',
#  'bass_synthetic_135-101-100',
#  'bass_synthetic_135-079-127',
#  'bass_synthetic_135-025-100',
#  'bass_synthetic_135-078-075',
#  'bass_synthetic_135-022-025',
#  'bass_synthetic_135-087-100',
#  'bass_synthetic_135-029-050',
#  'bass_synthetic_135-054-127',
#  'guitar_acoustic_014-089-127',
#  'guitar_acoustic_014-059-025',
#  'guitar_acoustic_014-045-127',
#  'guitar_acoustic_014-082-050',
#  'guitar_acoustic_014-075-127',
#  'guitar_acoustic_014-056-127',
#  'guitar_acoustic_014-023-127',
#  'guitar_acoustic_014-097-050',
#  'guitar_acoustic_014-070-025',
#  'guitar_acoustic_014-057-127',
#  'guitar_acoustic_014-035-100',
#  'guitar_acoustic_014-072-050',
#  'guitar_acoustic_014-024-050',
#  'guitar_acoustic_014-093-050',
#  'guitar_acoustic_014-030-100',
#  'guitar_acoustic_014-035-075',
#  'guitar_acoustic_014-039-050',
#  'guitar_acoustic_014-082-025',
#  'guitar_acoustic_014-037-100',
#  'guitar_acoustic_014-065-075',
#  'guitar_acoustic_014-090-127',
#  'guitar_acoustic_014-081-127',
#  'guitar_acoustic_014-073-127',
#  'guitar_acoustic_014-087-025',
#  'guitar_acoustic_014-048-075',
#  'guitar_acoustic_014-062-050',
#  'guitar_acoustic_014-023-075',
#  'guitar_acoustic_014-025-075',
#  'guitar_acoustic_014-033-050',
#  'guitar_acoustic_014-078-025',
#  'guitar_acoustic_014-080-127',
#  'guitar_acoustic_014-064-127',
#  'guitar_acoustic_014-035-127',
#  'guitar_acoustic_014-059-127',
#  'guitar_acoustic_014-093-100',
#  'guitar_acoustic_014-099-127',
#  'guitar_acoustic_014-056-050',
#  'guitar_acoustic_014-049-127',
#  'guitar_acoustic_014-047-050',
#  'guitar_acoustic_014-064-050',
#  'guitar_acoustic_014-059-050',
#  'guitar_acoustic_014-051-050',
#  'guitar_acoustic_014-059-100',
#  'guitar_acoustic_014-026-127',
#  'guitar_acoustic_014-048-050',
#  'guitar_acoustic_014-038-025',
#  'guitar_acoustic_014-024-127',
#  'guitar_acoustic_014-054-075',
#  'guitar_acoustic_014-027-075',
#  'guitar_acoustic_014-039-075',
#  'guitar_acoustic_014-088-100',
#  'guitar_acoustic_014-034-025',
#  'guitar_acoustic_014-041-100',
#  'guitar_acoustic_014-106-025',
#  'guitar_acoustic_014-101-100',
#  'guitar_acoustic_014-039-127',
#  'guitar_acoustic_014-031-100',
#  'guitar_acoustic_014-054-025',
#  'guitar_acoustic_014-082-100',
#  'guitar_acoustic_014-026-050',
#  'guitar_acoustic_014-074-050',
#  'guitar_acoustic_014-085-100',
#  'guitar_acoustic_014-077-100',
#  'guitar_acoustic_014-050-025',
#  'guitar_acoustic_014-049-075',
#  'guitar_acoustic_014-083-025',
#  'guitar_acoustic_014-044-127',
#  'guitar_acoustic_014-098-025',
#  'guitar_acoustic_014-043-127',
#  'guitar_acoustic_014-071-100',
#  'guitar_acoustic_014-058-127',
#  'guitar_acoustic_014-080-075',
#  'guitar_acoustic_014-034-127',
#  'guitar_acoustic_014-049-025',
#  'guitar_acoustic_014-033-025',
#  'guitar_acoustic_014-051-127',
#  'guitar_acoustic_014-031-075',
#  'guitar_acoustic_014-085-025',
#  'guitar_acoustic_014-077-075',
#  'guitar_acoustic_014-103-127',
#  'guitar_acoustic_014-067-025',
#  'guitar_acoustic_014-105-075',
#  'guitar_acoustic_014-073-075',
#  'guitar_acoustic_014-025-025',
#  'guitar_acoustic_014-077-127',
#  'guitar_acoustic_014-039-100',
#  'guitar_acoustic_014-061-075',
#  'guitar_acoustic_014-058-100',
#  'guitar_acoustic_014-058-075',
#  'guitar_acoustic_014-104-075',
#  'guitar_acoustic_014-043-100',
#  'guitar_acoustic_014-062-100',
#  'guitar_acoustic_014-032-050',
#  'guitar_acoustic_014-045-075',
#  'guitar_acoustic_014-100-025',
#  'guitar_acoustic_014-089-075',
#  'guitar_acoustic_014-078-127',
#  'guitar_acoustic_014-066-075',
#  'guitar_acoustic_014-065-100',
#  'guitar_acoustic_014-021-100',
#  'guitar_acoustic_014-028-075',
#  'guitar_acoustic_014-050-100',
#  'guitar_acoustic_014-091-050',
#  'guitar_acoustic_014-038-100',
#  'guitar_acoustic_014-028-127',
#  'guitar_acoustic_014-040-075',
#  'guitar_acoustic_014-085-075',
#  'guitar_acoustic_014-101-025',
#  'guitar_acoustic_014-032-127',
#  'guitar_acoustic_014-048-025',
#  'guitar_acoustic_014-047-025',
#  'guitar_acoustic_014-038-050',
#  'guitar_acoustic_014-097-025',
#  'guitar_acoustic_014-098-100',
#  'guitar_acoustic_014-107-075',
#  'guitar_acoustic_014-055-025',
#  'guitar_acoustic_014-055-075',
#  'guitar_acoustic_014-095-100',
#  'guitar_acoustic_014-075-075',
#  'guitar_acoustic_014-098-075',
#  'guitar_acoustic_014-074-100',
#  'guitar_acoustic_014-087-127',
#  'guitar_acoustic_014-073-025',
#  'guitar_acoustic_014-068-025',
#  'guitar_acoustic_014-071-075',
#  'guitar_acoustic_014-055-050',
#  'guitar_acoustic_014-027-127',
#  'guitar_acoustic_014-096-100',
#  'guitar_acoustic_014-100-075',
#  'guitar_acoustic_014-097-100',
#  'guitar_acoustic_014-095-025',
#  'guitar_acoustic_014-031-025',
#  'guitar_acoustic_014-037-127',
#  'guitar_acoustic_014-041-075',
#  'guitar_acoustic_014-040-100',
#  'guitar_acoustic_014-022-050',
#  'guitar_acoustic_014-047-127',
#  'guitar_acoustic_014-044-050',
#  'guitar_acoustic_014-103-100',
#  'guitar_acoustic_014-092-127',
#  'guitar_acoustic_014-032-100',
#  'guitar_acoustic_014-041-050',
#  'guitar_acoustic_014-091-127',
#  'guitar_acoustic_014-023-100',
#  'guitar_acoustic_014-057-050',
#  'guitar_acoustic_014-107-025',
#  'guitar_acoustic_014-079-100',
#  'guitar_acoustic_014-090-100',
#  'guitar_acoustic_014-070-127',
#  'guitar_acoustic_014-067-075',
#  'guitar_acoustic_014-063-025',
#  'guitar_acoustic_014-082-127',
#  'guitar_acoustic_014-063-075',
#  'guitar_acoustic_014-087-100',
#  'guitar_acoustic_014-066-025',
#  'guitar_acoustic_014-065-025',
#  'guitar_acoustic_014-083-127',
#  'guitar_acoustic_014-030-075',
#  'guitar_acoustic_014-094-127',
#  'guitar_acoustic_014-048-127',
#  'guitar_acoustic_014-106-075',
#  'guitar_acoustic_014-046-127',
#  'guitar_acoustic_014-086-127',
#  'guitar_acoustic_014-084-050',
#  'guitar_acoustic_014-060-075',
#  'guitar_acoustic_014-088-127',
#  'guitar_acoustic_014-046-100',
#  'guitar_acoustic_014-066-127',
#  'guitar_acoustic_014-072-127',
#  'guitar_acoustic_014-051-025',
#  'guitar_acoustic_014-028-025',
#  'guitar_acoustic_014-049-100',
#  'guitar_acoustic_014-041-127',
#  'guitar_acoustic_014-029-025',
#  'guitar_acoustic_014-074-025',
#  'guitar_acoustic_014-040-127',
#  'guitar_acoustic_014-107-127',
#  'guitar_acoustic_014-068-075',
#  'guitar_acoustic_014-081-100',
#  'guitar_acoustic_014-028-100',
#  'guitar_acoustic_014-051-100',
#  'guitar_acoustic_014-022-025',
#  'guitar_acoustic_014-024-025',
#  'guitar_acoustic_014-029-050',
#  'guitar_acoustic_014-098-050',
#  'guitar_acoustic_014-069-100',
#  'guitar_acoustic_014-053-050',
#  'guitar_acoustic_014-067-050',
#  'guitar_acoustic_014-108-127',
#  'guitar_acoustic_014-094-075',
#  'guitar_acoustic_014-033-100',
#  'guitar_acoustic_014-030-050',
#  'guitar_acoustic_014-096-025',
#  'guitar_acoustic_014-042-025',
#  'guitar_acoustic_014-106-127',
#  'guitar_acoustic_014-072-100',
#  'guitar_acoustic_014-105-127',
#  'guitar_acoustic_014-080-025',
#  'guitar_acoustic_014-031-127',
#  'guitar_acoustic_014-108-075',
#  'guitar_acoustic_014-037-050',
#  'guitar_acoustic_014-047-100',
#  'guitar_acoustic_014-046-025',
#  'guitar_acoustic_014-021-075',
#  'guitar_acoustic_014-034-050',
#  'guitar_acoustic_014-108-100',
#  'guitar_acoustic_014-086-050',
#  'guitar_acoustic_014-091-075',
#  'guitar_acoustic_014-089-025',
#  'guitar_acoustic_014-099-100',
#  'guitar_acoustic_014-098-127',
#  'guitar_acoustic_014-052-127',
#  'guitar_acoustic_014-090-025',
#  'guitar_acoustic_014-064-075',
#  'guitar_acoustic_014-106-050',
#  'guitar_acoustic_014-026-075',
#  'guitar_acoustic_014-103-025',
#  'guitar_acoustic_014-093-025',
#  'guitar_acoustic_014-042-050',
#  'guitar_acoustic_014-075-100',
#  'guitar_acoustic_014-092-075',
#  'guitar_acoustic_014-060-100',
#  'guitar_acoustic_014-102-075',
#  'guitar_acoustic_014-102-050',
#  'guitar_acoustic_014-096-127',
#  'guitar_acoustic_014-088-025',
#  'keyboard_synthetic_000-022-050',
#  'keyboard_synthetic_000-100-025',
#  'keyboard_synthetic_000-050-127',
#  'keyboard_synthetic_000-051-127',
#  'keyboard_synthetic_000-064-127',
#  'keyboard_synthetic_000-072-025',
#  'keyboard_synthetic_000-037-075',
#  'keyboard_synthetic_000-028-127',
#  'keyboard_synthetic_000-077-025',
#  'keyboard_synthetic_000-031-127',
#  ...]
